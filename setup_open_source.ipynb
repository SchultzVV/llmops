# %%
import os
tkn = os.getenv('HGFTKN')

# %%
## Llama-2-7b-chat-hf

from transformers import AutoModelForCausalLM, AutoTokenizer
import os

tkn = os.getenv('HGFTKN')

model_name = "meta-llama/Llama-2-7b-chat-hf"
tokenizer = AutoTokenizer.from_pretrained(model_name, token=tkn)

# tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# %%
##  Mistral-7B-v0.1

from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "mistralai/Mistral-7B-v0.1"  # Modelo open-source
tokenizer = AutoTokenizer.from_pretrained(model_name, token=tkn)
model = AutoModelForCausalLM.from_pretrained(model_name, token=tkn)
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       5 model_name = "mistralai/Mistral-7B-v0.1"  # Modelo open-source
#       6 tokenizer = AutoTokenizer.from_pretrained(model_name, token=tkn)
# ----> 7 model = AutoModelForCausalLM.from_pretrained(model_name, token=tkn)
#
# File ~/anaconda3/envs/nlp/lib/python3.13/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
# ...

# %%
## falcon-7b

from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "tiiuae/falcon-7b"  # Falcon 7B
# model_name = "tiiuae/falcon-40b"  # Falcon 40B (requer mais recursos)
tokenizer = AutoTokenizer.from_pretrained(model_name, token=tkn)
model = AutoModelForCausalLM.from_pretrained(model_name)

# %% [markdown]
# ![image.png](attachment:image.png)
# Tá falhando, não sei ao certo o pq os downloads dos modelos não acontecem.. Tenho vários gigas sobrando, mas se eles forem maiores que 200Gb talvez seja esse o problema do download. Mais tarde vou entrar na minha Acc da AWS e tentar baixar para o S3 e ver se resolve.

# %%
## gpt-j-6B

from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "EleutherAI/gpt-j-6B"  # GPT-J 6B
# model_name = "EleutherAI/gpt-neox-20b"  # GPT-NeoX 20B (requer mais recursos)
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# %%
## open_llama_7b

from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "openlm-research/open_llama_7b"  # OpenLLaMA 7B
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "HuggingFaceH4/zephyr-7b-alpha"  # Zephyr 7B
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# %% [markdown]
# #### Se falhar, baixa no dedo e carrega

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_path = "/caminho/para/pasta/do/modelo"  # Substitua pelo caminho da pasta onde os arquivos estão
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path)
